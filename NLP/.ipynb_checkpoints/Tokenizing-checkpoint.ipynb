# %%
import nltk
print("Hello")
texts = ["""The Golden Retriever is a large-sized breed of dog bred as gun dogs to retrieve shot waterfowl, such as ducks and
upland game birds, during hunting and shooting parties,[3] and were named 'retriever' because of their ability to retrieve
shot game undamaged (soft mouth). Golden retrievers have an instinctive love of water, and are easy to train to basic or
advanced obedience standards. They are a long-coated breed, with a dense inner coat that provides them with adequate warmth
in the outdoors, and an outer coat that lies flat against their bodies and repels water. Golden retrievers are well suited
to residency in suburban or country environments.[4] They shed copiously, particularly at the change of seasons, and require 
fairly regular grooming. The Golden Retriever was originally bred in Scotland in the mid-19th century."""]
# Out:
# Hello

# %%
for text in texts:
    sentences=nltk.sent_tokenize(text,language='english')
    for sentence in sentences:
        words=nltk.word_tokenize(sentence)
        tagged_words=nltk.pos_tag(words)
        print(tagged_words)
        ne_tagged_words=nltk.ne_chunk(tagged_words)
        print(ne_tagged_words)
# Out:
# [('The', 'DT'), ('Golden', 'NNP'), ('Retriever', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('large-sized', 'JJ'), ('breed', 'NN'), ('of', 'IN'), ('dog', 'NN'), ('bred', 'VBN'), ('as', 'IN'), ('gun', 'JJ'), ('dogs', 'NNS'), ('to', 'TO'), ('retrieve', 'VB'), ('shot', 'NN'), ('waterfowl', 'NN'), (',', ','), ('such', 'JJ'), ('as', 'IN'), ('ducks', 'NNS'), ('and', 'CC'), ('upland', 'JJ'), ('game', 'NN'), ('birds', 'NNS'), (',', ','), ('during', 'IN'), ('hunting', 'VBG'), ('and', 'CC'), ('shooting', 'VBG'), ('parties', 'NNS'), (',', ','), ('[', 'VBP'), ('3', 'CD'), (']', 'NNS'), ('and', 'CC'), ('were', 'VBD'), ('named', 'VBN'), ("'retriever", 'RB'), ("'", 'POS'), ('because', 'IN'), ('of', 'IN'), ('their', 'PRP$'), ('ability', 'NN'), ('to', 'TO'), ('retrieve', 'VB'), ('shot', 'JJ'), ('game', 'NN'), ('undamaged', 'VBD'), ('(', '('), ('soft', 'JJ'), ('mouth', 'NN'), (')', ')'), ('.', '.')]
# (S
#   The/DT
#   (ORGANIZATION Golden/NNP)
#   Retriever/NNP
#   is/VBZ
#   a/DT
#   large-sized/JJ
#   breed/NN
#   of/IN
#   dog/NN
#   bred/VBN
#   as/IN
#   gun/JJ
#   dogs/NNS
#   to/TO
#   retrieve/VB
#   shot/NN
#   waterfowl/NN
#   ,/,
#   such/JJ
#   as/IN
#   ducks/NNS
#   and/CC
#   upland/JJ
#   game/NN
#   birds/NNS
#   ,/,
#   during/IN
#   hunting/VBG
#   and/CC
#   shooting/VBG
#   parties/NNS
#   ,/,
#   [/VBP
#   3/CD
#   ]/NNS
#   and/CC
#   were/VBD
#   named/VBN
#   'retriever/RB
#   '/POS
#   because/IN
#   of/IN
#   their/PRP$
#   ability/NN
#   to/TO
#   retrieve/VB
#   shot/JJ
#   game/NN
#   undamaged/VBD
#   (/(
#   soft/JJ
#   mouth/NN
#   )/)
#   ./.)
# [('Golden', 'NNP'), ('retrievers', 'NNS'), ('have', 'VBP'), ('an', 'DT'), ('instinctive', 'JJ'), ('love', 'NN'), ('of', 'IN'), ('water', 'NN'), (',', ','), ('and', 'CC'), ('are', 'VBP'), ('easy', 'JJ'), ('to', 'TO'), ('train', 'VB'), ('to', 'TO'), ('basic', 'VB'), ('or', 'CC'), ('advanced', 'JJ'), ('obedience', 'NN'), ('standards', 'NNS'), ('.', '.')]
# (S
#   (GPE Golden/NNP)
#   retrievers/NNS
#   have/VBP
#   an/DT
#   instinctive/JJ
#   love/NN
#   of/IN
#   water/NN
#   ,/,
#   and/CC
#   are/VBP
#   easy/JJ
#   to/TO
#   train/VB
#   to/TO
#   basic/VB
#   or/CC
#   advanced/JJ
#   obedience/NN
#   standards/NNS
#   ./.)
# [('They', 'PRP'), ('are', 'VBP'), ('a', 'DT'), ('long-coated', 'JJ'), ('breed', 'NN'), (',', ','), ('with', 'IN'), ('a', 'DT'), ('dense', 'NN'), ('inner', 'NN'), ('coat', 'NN'), ('that', 'WDT'), ('provides', 'VBZ'), ('them', 'PRP'), ('with', 'IN'), ('adequate', 'JJ'), ('warmth', 'NN'), ('in', 'IN'), ('the', 'DT'), ('outdoors', 'NNS'), (',', ','), ('and', 'CC'), ('an', 'DT'), ('outer', 'NN'), ('coat', 'NN'), ('that', 'IN'), ('lies', 'VBZ'), ('flat', 'JJ'), ('against', 'IN'), ('their', 'PRP$'), ('bodies', 'NNS'), ('and', 'CC'), ('repels', 'NNS'), ('water', 'NN'), ('.', '.')]
# (S
#   They/PRP
#   are/VBP
#   a/DT
#   long-coated/JJ
#   breed/NN
#   ,/,
#   with/IN
#   a/DT
#   dense/NN
#   inner/NN
#   coat/NN
#   that/WDT
#   provides/VBZ
#   them/PRP
#   with/IN
#   adequate/JJ
#   warmth/NN
#   in/IN
#   the/DT
#   outdoors/NNS
#   ,/,
#   and/CC
#   an/DT
#   outer/NN
#   coat/NN
#   that/IN
#   lies/VBZ
#   flat/JJ
#   against/IN
#   their/PRP$
#   bodies/NNS
#   and/CC
#   repels/NNS
#   water/NN
#   ./.)
# [('Golden', 'JJ'), ('retrievers', 'NNS'), ('are', 'VBP'), ('well', 'RB'), ('suited', 'VBN'), ('to', 'TO'), ('residency', 'VB'), ('in', 'IN'), ('suburban', 'JJ'), ('or', 'CC'), ('country', 'NN'), ('environments', 'NNS'), ('.', '.')]
# (S
#   (GPE Golden/JJ)
#   retrievers/NNS
#   are/VBP
#   well/RB
#   suited/VBN
#   to/TO
#   residency/VB
#   in/IN
#   suburban/JJ
#   or/CC
#   country/NN
#   environments/NNS
#   ./.)
# [('[', 'RB'), ('4', 'CD'), (']', 'NN'), ('They', 'PRP'), ('shed', 'VBD'), ('copiously', 'RB'), (',', ','), ('particularly', 'RB'), ('at', 'IN'), ('the', 'DT'), ('change', 'NN'), ('of', 'IN'), ('seasons', 'NNS'), (',', ','), ('and', 'CC'), ('require', 'VBP'), ('fairly', 'RB'), ('regular', 'JJ'), ('grooming', 'NN'), ('.', '.')]
# (S
#   [/RB
#   4/CD
#   ]/NN
#   They/PRP
#   shed/VBD
#   copiously/RB
#   ,/,
#   particularly/RB
#   at/IN
#   the/DT
#   change/NN
#   of/IN
#   seasons/NNS
#   ,/,
#   and/CC
#   require/VBP
#   fairly/RB
#   regular/JJ
#   grooming/NN
#   ./.)
# [('The', 'DT'), ('Golden', 'NNP'), ('Retriever', 'NNP'), ('was', 'VBD'), ('originally', 'RB'), ('bred', 'VBN'), ('in', 'IN'), ('Scotland', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('mid-19th', 'JJ'), ('century', 'NN'), ('.', '.')]
# (S
#   The/DT
#   (ORGANIZATION Golden/NNP)
#   Retriever/NNP
#   was/VBD
#   originally/RB
#   bred/VBN
#   in/IN
#   (GPE Scotland/NNP)
#   in/IN
#   the/DT
#   mid-19th/JJ
#   century/NN
#   ./.)
